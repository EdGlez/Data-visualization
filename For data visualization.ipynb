# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [20, 21, 20.5, 20.8]

# %%
plt.plot(x, y, linestyle="dashed", marker="o", color="green")
plt.show()

# %%
X, Y = [], []
for line in open('matplot.txt', 'r'):
    values = [float(s) for s in line.split()]
    X.append(values[0])
    Y.append(values[1])
plt.plot(X,Y)
plt.show()

# %%
import numpy as np
data = np.random.rand(124, 2)
plt.scatter(data[:1], data[:1])

plt.show()

# %%
# %matplotlib inline
import pandas as pd

# %%
raw_data = {'first_name': ['Mike', 'Brad', 'Chan', 'Dee', 'Stan'], 
        'last_name': ['Miller', 'Smith', 'Man', 'Milner', 'Chin'], 
        'female': [0, 1, 1, 0, 1],
        'age': [42, 52, 36, 24, 73], 
        'preTestScore': [4, 24, 31, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70]}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'age', 'female', 'preTestScore', 'postTestScore'])
df
# Out:
#   first_name last_name  age  female  preTestScore  postTestScore
# 0       Mike    Miller   42       0             4             25
# 1       Brad     Smith   52       1            24             94
# 2       Chan       Man   36       1            31             57
# 3        Dee    Milner   24       0             2             62
# 4       Stan      Chin   73       1             3             70

# %%
plt.scatter(df.preTestScore, df.postTestScore, s=df.age)

# %%
plt.scatter(df.preTestScore, df.postTestScore, s=300, c=df.female)

# %%
data = [5., 25., 50., 20.5]
plt.bar(range(len(data)), data, width = 1.)
plt.show()

# %%
data = [5., 25., 50., 20.5]
plt.barh(range(len(data)), data)
plt.show()

# %%
data = [[5., 25., 50., 20.5],
        [4., 23., 51., 17.],
        [6., 22., 52., 19.]]
X = np.arange(4)
plt.bar(X + 0.00, data[0], color = 'b', width = 0.25)
plt.bar(X + 0.25, data[1], color = 'g', width = 0.25)
plt.bar(X + 0.50, data[2], color = 'r', width = 0.25)
plt.show()

# %%
A = [5., 30., 45., 22.]
B = [5., 25., 50., 20.]
X = range(4)
plt.bar(X, A, color = 'g')
plt.bar(X, B, color = 'r', bottom = A)

plt.show()

# %%
A = np.array([5., 30., 45., 22.]) 
B = np.array([5., 25., 50., 20.]) 
C = np.array([3.,  4.,  12.,  11.])
X = np.arange(4)
plt.bar(X, A, color = 'b') 
plt.bar(X, B, color = 'g', bottom = A) 
plt.bar(X, C, color = 'r', bottom = A + B)

plt.show()

# %%
data = [5, 25, 50, 20]
plt.pie(data)
plt.show()

# %%
X = np.random.rand(1000)
plt.hist(X, bins=20)
plt.show()

# %%
testscores= [62, 50,90, 55, 92, 80, 84, 88, 98, 54, 72, 60,68,
             94, 77, 86, 92, 32, 65, 86, 95]
bins=[30,40,50,60,70,80,90,100]
plt.hist(testscores, bins, histtype='bar', rwidth=0.8, cumulative=True)
plt.show()

# %%
data = np.random.rand(100)
plt.boxplot(data)
plt.show()

# %%
data = np.random.randn(100, 5)
plt.boxplot(data)
plt.show()

# %%
import matplotlib.tri as tri
data = np.random.rand(100, 2)
triangles = tri.Triangulation(data[:,0], data[:,1])

plt.triplot(triangles)
plt.show()

# %%
def pdf(X, mu, sigma):
    a = 1. / (sigma * np.sqrt(2. * np.pi))
    b = -1. / (2. * sigma ** 2)
    return a * np.exp(b * (X - mu) ** 2)
X = np.linspace(-6, 6, 1000)
for i in range(5):
    samples = np.random.standard_normal(50)
    mu, sigma = np.mean(samples), np.std(samples)
    plt.plot(X, pdf(X, mu, sigma), color = '.75')

plt.plot(X, pdf(X, 0., 1.), color='k')
plt.show()

# %%
label_set = (  b'Iris-setosa',  b'Iris-versicolor',  b'Iris-virginica', )
def read_label(label):  
    return label_set.index(label)
data = np.loadtxt('Iris.txt',                             
                  delimiter = ',',                             
                  converters = { 4 : read_label })
color_set = ('.20', '.55', '.90') 
color_list = [color_set[int(label)] 
              for label in data[:,4]]
plt.scatter(data[:,0], data[:,1], color = color_list) 
plt.show()

# %%
values = np.random.randint(99, size = 50)
color_set =('r', 'g', 'b', 'm')  
color_list = [color_set[(len(color_set) * val) // 100] 
              for val in    values]
plt.bar(np.arange(len(values)), values, color = color_list) 
plt.show()

# %%
#Controlling pattern and fill
N = 8 
A = np.random.random(N)
B = np.random.random(N) 
X = np.arange(N)
#C = np.random.random(N)

plt.bar(X, A, color = '.45', hatch = 'x') 
plt.bar(X, A + B, bottom = A, color = '.89', hatch = '/')
#plt.bar(X, C, bottom = A + C, color = 'r', hatch = '\\')
plt.show()

# %%
#Into markers
A = np.random.standard_normal((100,2))
A += np.array((-1,-1))
B = np.random.standard_normal((100,2))
B += np.array((-1,-1))

plt.scatter(B[:,0], B[:,1], c='.65', s=100., marker='*')
plt.scatter(A[:,0], A[:,1], c='.30', s=25., marker='^' )
plt.show()

# %%
#controlling marker frequency
X = np.linspace(-6, 6, 1024) 
Y1 = np.sinc(X) 
Y2 = np.sinc(X) + 1

plt.plot(X, Y1, marker = 'o', color = '.45',markevery = 25) 
plt.plot(X, Y2, marker = 'o', color = 'k', markevery = 50)
plt.show()

# %%
x = np.arange(0.0,50.0,2.0)
y = x ** 1.3 + np.random.rand(*x.shape) * 30.0
s = np.random.rand(*x.shape) * 800 + 500

plt.scatter(x,y,s, c='g', alpha=0.5, marker = r'$\clubsuit$', label = 'Training')
plt.xlabel("Movement")
plt.ylabel("Success")
plt.legend(loc=2)
plt.show()

# %%
M = np.random.standard_normal((1000, 2)) 
R = np.sum(M ** 2, axis = 1)
plt.scatter(M[:, 0], M[:, 1], c = 'b', marker = 's', s = 10 * R) 
plt.show()

# %%
#Personalized color schemes
import matplotlib as mpl

mpl.rc('lines', linewidth=2.0)
mpl.rc('axes', facecolor = 'k', edgecolor='w')
mpl.rc('xtick', color='w')
mpl.rc('ytick', color='w')
mpl.rc('text', color='w')
mpl.rc('figure', facecolor='k', edgecolor='w')

X= np.linspace(0,7,1024)
plt.plot(X, np.sin(X))
plt.plot(X, np.cos(X))
plt.show()

# %%
#Exporting graphs to png, pdf, etc...

X = np.linspace(-10, 10, 1024) 
Y = np.sinc(X)

plt.plot(X, Y) 
plt.savefig('graph.png', c = 'k')
#plt.savefig('graph.pdf')

# %%
#Adding text anywhere
X = np.linspace(-4, 4, 1024) 
Y = .25 * (X + 4.) * (X + 1.) * (X - 2.)
plt.text(-0.3, -0.28, 'Nice Curve')
plt.plot(X, Y, c = 'w') 
plt.show()

# %%
#Adding a grid to a chart
X = np.linspace(-4, 4, 1024) 
Y = .25 * (X + 4.) * (X + 1.) * (X - 2.)
plt.plot(X, Y, c = 'w') 
plt.grid(True, lw = 2, ls = '--', c = '.75') 
plt.show()

# %%
#Labelling our ticks
import numpy as np 
import matplotlib.ticker as ticker 
import matplotlib.pyplot as plt

name_list = ('Mike', 'Brad', 'Stan', 'Jon', 'Matt') 
value_list = np.random.randint(0, 99, size = len(name_list)) 
pos_list = np.arange(len(name_list))

ax = plt.axes() 
ax.xaxis.set_major_locator(ticker.FixedLocator((pos_list))) 
ax.xaxis.set_major_formatter(ticker.FixedFormatter((name_list)))

plt.bar(pos_list, value_list, color = '.75', align = 'center') 
plt.show()

# %%
import seaborn as sns

data = np.random.normal(size=(20, 6)) + np.arange(6) / 2

sns.set_style("whitegrid")
sns.boxplot(data=data)
plt.title("whitegrid")
plt.show()

sns.set_style("darkgrid")
sns.boxplot(data=data);
plt.title("darkgrid")
plt.show()

sns.set_style("white")
sns.boxplot(data=data);
plt.title("white")
plt.show()

sns.set_style("dark")
sns.boxplot(data=data);
plt.title("dark")
plt.show()

sns.set_style("ticks")
sns.boxplot(data=data);
plt.title("ticks")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_context("notebook", font_scale=1, rc={"font.size":3,"axes.labelsize":15})

iris = sns.load_dataset("iris")

sns.swarmplot(x="species", y="petal_length", data=iris)

plt.show()

# %%
titanic = sns.load_dataset("titanic")

g = sns.factorplot("class", "survived", "sex", data=titanic, kind="bar", size=3, aspect=3, palette="muted", legend=False)

plt.show()

# %%
import pandas as pd

x = 10 ** np.arange(1, 10)
y = x * 2
data = pd.DataFrame(data={'x': x, 'y': y})

grid = sns.lmplot('x', 'y', data, size=7, truncate=True, scatter_kws={"s": 100})
grid.set_xticklabels(rotation=90)

plt.show()
# Out:
# C:\Users\sexyb\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
